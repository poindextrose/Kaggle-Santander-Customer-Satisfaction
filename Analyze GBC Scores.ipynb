# %%
from pymongo import MongoClient
import pandas as pd
from pandas.io.json import json_normalize
import numpy as np

client = MongoClient("mongodb://optimizer:bOQ0QxKl1oKX@ds015760.mlab.com:15760/santander")
db = client.santander

# %%
# df = pd.read_json(
results = db.gbc_fs_scores.find({"mean_score":{"$gt":0.835}},{"mean_score":1,"params":1})
df = json_normalize(list(results))
del df['_id']
df.describe()
# Out:
#        mean_score  params.gbc__learning_rate  params.gbc__max_depth  \
# count  401.000000                 401.000000             401.000000
# mean     0.836651                   0.082345               7.778055
# std      0.001124                   0.053234               3.515411
# min      0.835077                   0.005244               2.000000
# 25%      0.835764                   0.041451               5.000000
# 50%      0.836455                   0.072854               7.000000
# 75%      0.837370                   0.107926              11.000000
# max      0.841132                   0.342065              14.000000
#
#        params.gbc__min_samples_leaf  params.gbc__min_samples_split  \
# count                    401.000000                     401.000000
# mean                       1.483791                       3.518703
# std                        0.500361                       1.090997
# min                        1.000000                       2.000000
# 25%                        1.000000                       3.000000
# 50%                        1.000000                       3.000000
# 75%                        2.000000                       4.000000
# max                        2.000000                       5.000000
#
#        params.gbc__min_weight_fraction_leaf  params.gbc__n_estimators  \
# count                            401.000000                401.000000
# mean                               0.049150                290.244389
# std                                0.027614                123.026746
# min                                0.000217                 36.000000
# 25%                                0.027615                186.000000
# 50%                                0.049072                303.000000
# 75%                                0.069345                387.000000
# max                                0.114325                499.000000
#
#        params.gbc__subsample  params.selector__percentile
# count             401.000000                   401.000000
# mean                0.743287                    59.728180
# std                 0.147032                    22.907279
# min                 0.500240                    14.000000
# 25%                 0.612865                    41.000000
# 50%                 0.742833                    59.000000
# 75%                 0.866293                    81.000000
# max                 0.999975                    99.000000
